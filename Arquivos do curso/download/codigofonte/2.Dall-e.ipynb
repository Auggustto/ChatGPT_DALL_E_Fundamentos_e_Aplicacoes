# %%
import openai

#chave de autenticação
openai.api_key = "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"

response = openai.Image.create(
    prompt = "crie uma imagem 3d de um disco voador na cor verde",
    size = "512x512",
    n = 1,
    response_format = "url"
)
print(response["data"][0]["url"])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-RWIUsbsC4u9IXctF8XWAojA4.png?st=2023-01-03T22%3A02%3A30Z&se=2023-01-04T00%3A02%3A30Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-03T18%3A43%3A50Z&ske=2023-01-04T18%3A43%3A50Z&sks=b&skv=2021-08-06&sig=Vx8eqDHVHYzHp3Qg0z95Pu3FH%2BFjLoTHZtrv5eMNGM4%3D

# %%
import openai
from io import BytesIO
import requests
from PIL import Image

#chave de autenticação
openai.api_key = "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"

response = openai.Image.create(
    prompt = "crie uma imagem de um computador antigo",
    size = "256x256",
    n = 1,
    response_format = "url"
)
response = requests.get(response["data"][0]["url"])
Image.open(BytesIO(response.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x2224E223BE0>

# %%
import openai
import base64
from IPython.display import display
from PIL import Image

#chave de autenticação
openai.api_key = "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"

response = openai.Image.create(
    prompt = "crie a imagem de um iate cor de rosa",
    size = "512x512",
    n = 1,
    response_format = "b64_json"
)
#recebe a resposta
imagem = response["data"][0]["b64_json"]
#transforma em imagem
imagem = base64.b64decode(imagem)

with open("iate.png", "wb") as f:
    f.write(imagem)

display(Image.open("iate.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x2224E580220>

# %%
#png com menos de 4mb, mesma altura e largura
import openai

#chave de autenticação
openai.api_key = "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"

response = openai.Image.create_variation(
    image=open("moto.png","rb"),
    size = "1024x1024",
    n = 1,
    response_format = "url"
)
print(response["data"][0]["url"])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-bt77GuesV0ki8LBgdt9Y8HZ2.png?st=2023-01-03T22%3A28%3A28Z&se=2023-01-04T00%3A28%3A28Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-03T21%3A50%3A07Z&ske=2023-01-04T21%3A50%3A07Z&sks=b&skv=2021-08-06&sig=YQ2U59zZeA0ZNUt3WRyUWuyCdAJaeNbXZv3IhAdQyNw%3D

# %%
import openai

#chave de autenticação
openai.api_key = "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"

response = openai.Image.create_edit(
    image=open("motomask.png","rb"),
    mask=open("DALL·E 2023-01-02 12.58.52.png","rb"),
    prompt="a motocycle with a big blue airplane",
    size = "1024x1024",
    n = 1,
    response_format = "url"
)
print(response["data"][0]["url"])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-GG4FgdsC7pjFXZUzJaf0Lg0F/user-EKimdtZ0sFPHREewg6LEw2r4/img-i3w2YHaidYHH0oDNH5y5yLbq.png?st=2023-01-03T22%3A39%3A29Z&se=2023-01-04T00%3A39%3A29Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-03T19%3A25%3A22Z&ske=2023-01-04T19%3A25%3A22Z&sks=b&skv=2021-08-06&sig=Y/hPgq/DGwOA3oqXygrdUcwktl66DsKeTalZ78eAVE8%3D
